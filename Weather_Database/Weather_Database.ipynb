# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
import pprint

# import the library for API requests   
import requests
requests.__version__

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random 2000 latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_desc=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Country": city_country,
                            "Date": city_date, 
                            "Current Description": city_current_desc
                            })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | campbellsville
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | mehamn
# Processing Record 4 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | bambous virieux
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | coihaique
# Processing Record 9 of Set 1 | rondonopolis
# Processing Record 10 of Set 1 | bethel
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | beloha
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | dudinka
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | talnakh
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | sayyan
# Processing Record 23 of Set 1 | batticaloa
# Processing Record 24 of Set 1 | oranjemund
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | lorengau
# Processing Record 29 of Set 1 | pisco
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | sorong
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | linxia
# Processing Record 34 of Set 1 | sitka
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | baruun-urt
# Processing Record 37 of Set 1 | new norfolk
# Processing Record 38 of Set 1 | bluff
# Processing Record 39 of Set 1 | birao
# Processing Record 40 of Set 1 | hlatikulu
# Processing Record 41 of Set 1 | revin
# Processing Record 42 of Set 1 | sogdiondon
# City not found. Skipping...
# Processing Record 43 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 1 | kyabe
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | storm lake
# Processing Record 47 of Set 1 | fort nelson
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | kodiak
# Processing Record 50 of Set 1 | mendi
# Processing Record 1 of Set 2 | exu
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | mantua
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | chifeng
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | ahipara
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | chuy
# Processing Record 12 of Set 2 | east london
# Processing Record 13 of Set 2 | teguise
# Processing Record 14 of Set 2 | aldan
# Processing Record 15 of Set 2 | safaga
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | ponta delgada
# Processing Record 18 of Set 2 | yellowknife
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | gulshat
# City not found. Skipping...
# Processing Record 22 of Set 2 | zhengjiatun
# Processing Record 23 of Set 2 | barrow
# Processing Record 24 of Set 2 | khorixas
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | tutoia
# Processing Record 27 of Set 2 | hilo
# Processing Record 28 of Set 2 | vostok
# Processing Record 29 of Set 2 | kahului
# Processing Record 30 of Set 2 | hithadhoo
# Processing Record 31 of Set 2 | praia da vitoria
# Processing Record 32 of Set 2 | avera
# Processing Record 33 of Set 2 | arraial do cabo
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | butembo
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | south sioux city
# Processing Record 38 of Set 2 | guerrero negro
# Processing Record 39 of Set 2 | baykit
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | namibe
# Processing Record 42 of Set 2 | el bordo
# Processing Record 43 of Set 2 | torbay
# Processing Record 44 of Set 2 | taltal
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | axim
# Processing Record 48 of Set 2 | pacific grove
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | coahuayana
# Processing Record 1 of Set 3 | porto walter
# Processing Record 2 of Set 3 | gamba
# Processing Record 3 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | dzaoudzi
# Processing Record 6 of Set 3 | iquique
# Processing Record 7 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 3 | morant bay
# Processing Record 9 of Set 3 | banepa
# Processing Record 10 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 3 | barranca
# Processing Record 12 of Set 3 | itarema
# Processing Record 13 of Set 3 | beian
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 3 | casper
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 19 of Set 3 | kindu
# Processing Record 20 of Set 3 | kasese
# Processing Record 21 of Set 3 | aswan
# Processing Record 22 of Set 3 | daru
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | coalcoman
# City not found. Skipping...
# Processing Record 25 of Set 3 | clyde river
# Processing Record 26 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 3 | bredasdorp
# Processing Record 28 of Set 3 | margate
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | zaysan
# Processing Record 31 of Set 3 | yima
# Processing Record 32 of Set 3 | north bend
# Processing Record 33 of Set 3 | lakselv
# Processing Record 34 of Set 3 | alot
# Processing Record 35 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 36 of Set 3 | conde
# Processing Record 37 of Set 3 | miass
# Processing Record 38 of Set 3 | carutapera
# Processing Record 39 of Set 3 | qaqortoq
# Processing Record 40 of Set 3 | nanortalik
# Processing Record 41 of Set 3 | yarmouth
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | san quintin
# Processing Record 44 of Set 3 | ukiah
# Processing Record 45 of Set 3 | nikolskoye
# Processing Record 46 of Set 3 | souillac
# Processing Record 47 of Set 3 | beira
# Processing Record 48 of Set 3 | mahajanga
# Processing Record 49 of Set 3 | drabiv
# Processing Record 50 of Set 3 | katherine
# Processing Record 1 of Set 4 | muzhi
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | bonga
# Processing Record 4 of Set 4 | pangnirtung
# Processing Record 5 of Set 4 | broome
# Processing Record 6 of Set 4 | kaabong
# Processing Record 7 of Set 4 | port antonio
# Processing Record 8 of Set 4 | portland
# Processing Record 9 of Set 4 | korla
# Processing Record 10 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 4 | nova olimpia
# Processing Record 12 of Set 4 | maningrida
# Processing Record 13 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 14 of Set 4 | tessalit
# Processing Record 15 of Set 4 | senneterre
# Processing Record 16 of Set 4 | hammond
# Processing Record 17 of Set 4 | yunjinghong
# City not found. Skipping...
# Processing Record 18 of Set 4 | haines junction
# Processing Record 19 of Set 4 | cabo san lucas
# Processing Record 20 of Set 4 | rio grande
# Processing Record 21 of Set 4 | kvareli
# Processing Record 22 of Set 4 | panjab
# Processing Record 23 of Set 4 | rabo de peixe
# Processing Record 24 of Set 4 | cockburn town
# Processing Record 25 of Set 4 | mitsamiouli
# Processing Record 26 of Set 4 | porto santo
# Processing Record 27 of Set 4 | obera
# Processing Record 28 of Set 4 | waddan
# Processing Record 29 of Set 4 | ixtapa
# Processing Record 30 of Set 4 | funadhoo
# Processing Record 31 of Set 4 | hopkinsville
# Processing Record 32 of Set 4 | lucapa
# Processing Record 33 of Set 4 | sola
# Processing Record 34 of Set 4 | altamira
# Processing Record 35 of Set 4 | blora
# Processing Record 36 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 37 of Set 4 | stoyba
# City not found. Skipping...
# Processing Record 38 of Set 4 | mococa
# Processing Record 39 of Set 4 | tromso
# Processing Record 40 of Set 4 | marapanim
# Processing Record 41 of Set 4 | ronne
# Processing Record 42 of Set 4 | mogadishu
# Processing Record 43 of Set 4 | kamariotissa
# Processing Record 44 of Set 4 | los llanos de aridane
# Processing Record 45 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | codrington
# Processing Record 48 of Set 4 | brae
# Processing Record 49 of Set 4 | port hardy
# Processing Record 50 of Set 4 | vadso
# Processing Record 1 of Set 5 | bucerias
# Processing Record 2 of Set 5 | fairbanks
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | luderitz
# Processing Record 5 of Set 5 | la rioja
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 5 | lindi
# Processing Record 9 of Set 5 | xichang
# Processing Record 10 of Set 5 | deputatskiy
# Processing Record 11 of Set 5 | casino
# Processing Record 12 of Set 5 | kudahuvadhoo
# Processing Record 13 of Set 5 | divnomorskoye
# Processing Record 14 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 5 | nouadhibou
# Processing Record 16 of Set 5 | meulaboh
# Processing Record 17 of Set 5 | ribeira grande
# Processing Record 18 of Set 5 | matay
# Processing Record 19 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 20 of Set 5 | tomatlan
# Processing Record 21 of Set 5 | talcahuano
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | sinnamary
# Processing Record 24 of Set 5 | hami
# Processing Record 25 of Set 5 | tucurui
# Processing Record 26 of Set 5 | te anau
# Processing Record 27 of Set 5 | santa catarina de tepehuanes
# Processing Record 28 of Set 5 | iqaluit
# Processing Record 29 of Set 5 | tura
# Processing Record 30 of Set 5 | tuktoyaktuk
# Processing Record 31 of Set 5 | kamaishi
# Processing Record 32 of Set 5 | cherskiy
# Processing Record 33 of Set 5 | aleksandrov gay
# Processing Record 34 of Set 5 | jimo
# Processing Record 35 of Set 5 | leningradskiy
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 5 | cassilandia
# Processing Record 39 of Set 5 | tomigusuku
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | obo
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | viedma
# Processing Record 44 of Set 5 | la ronge
# Processing Record 45 of Set 5 | kavaratti
# Processing Record 46 of Set 5 | kangaatsiaq
# Processing Record 47 of Set 5 | mednogorsk
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | kuito
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | nipawin
# Processing Record 2 of Set 6 | elizabethton
# Processing Record 3 of Set 6 | cananea
# Processing Record 4 of Set 6 | cabedelo
# Processing Record 5 of Set 6 | primorsk
# Processing Record 6 of Set 6 | faya
# Processing Record 7 of Set 6 | carnarvon
# Processing Record 8 of Set 6 | pevek
# Processing Record 9 of Set 6 | beringovskiy
# Processing Record 10 of Set 6 | floro
# Processing Record 11 of Set 6 | sume
# Processing Record 12 of Set 6 | passagem franca
# Processing Record 13 of Set 6 | college
# Processing Record 14 of Set 6 | duluth
# Processing Record 15 of Set 6 | fare
# Processing Record 16 of Set 6 | longyearbyen
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | valparaiso
# Processing Record 19 of Set 6 | harwich
# Processing Record 20 of Set 6 | taoudenni
# Processing Record 21 of Set 6 | gander
# Processing Record 22 of Set 6 | sonoita
# Processing Record 23 of Set 6 | ekibastuz
# Processing Record 24 of Set 6 | san juan
# Processing Record 25 of Set 6 | kenai
# Processing Record 26 of Set 6 | saint-philippe
# Processing Record 27 of Set 6 | tarakan
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | rundu
# Processing Record 30 of Set 6 | kyra
# Processing Record 31 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 6 | mocuba
# Processing Record 33 of Set 6 | tiarei
# Processing Record 34 of Set 6 | san isidro
# Processing Record 35 of Set 6 | kampot
# Processing Record 36 of Set 6 | skeldon
# Processing Record 37 of Set 6 | bandarbeyla
# Processing Record 38 of Set 6 | san policarpo
# Processing Record 39 of Set 6 | vanimo
# Processing Record 40 of Set 6 | makung
# City not found. Skipping...
# Processing Record 41 of Set 6 | lazaro cardenas
# Processing Record 42 of Set 6 | buraydah
# Processing Record 43 of Set 6 | heilbron
# Processing Record 44 of Set 6 | ilheus
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | karratha
# Processing Record 47 of Set 6 | tagpangi
# City not found. Skipping...
# Processing Record 48 of Set 6 | ziniare
# Processing Record 49 of Set 6 | laguna
# Processing Record 50 of Set 6 | laramie
# Processing Record 1 of Set 7 | muros
# Processing Record 2 of Set 7 | asuncion
# Processing Record 3 of Set 7 | henties bay
# Processing Record 4 of Set 7 | acapulco
# Processing Record 5 of Set 7 | la peca
# Processing Record 6 of Set 7 | kavieng
# Processing Record 7 of Set 7 | atar
# Processing Record 8 of Set 7 | pitmoaga
# Processing Record 9 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 7 | acarau
# Processing Record 11 of Set 7 | galesong
# Processing Record 12 of Set 7 | charlottetown
# Processing Record 13 of Set 7 | adrar
# Processing Record 14 of Set 7 | erenhot
# Processing Record 15 of Set 7 | hasaki
# Processing Record 16 of Set 7 | nome
# Processing Record 17 of Set 7 | tual
# Processing Record 18 of Set 7 | sedro-woolley
# Processing Record 19 of Set 7 | terrace
# Processing Record 20 of Set 7 | banjar
# Processing Record 21 of Set 7 | hambantota
# Processing Record 22 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 7 | wanning
# Processing Record 24 of Set 7 | limon
# Processing Record 25 of Set 7 | bengkulu
# Processing Record 26 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 7 | tadine
# Processing Record 28 of Set 7 | okato
# Processing Record 29 of Set 7 | kabansk
# Processing Record 30 of Set 7 | luba
# Processing Record 31 of Set 7 | aksu
# Processing Record 32 of Set 7 | burnie
# Processing Record 33 of Set 7 | narsaq
# Processing Record 34 of Set 7 | bambanglipuro
# Processing Record 35 of Set 7 | teahupoo
# Processing Record 36 of Set 7 | lubango
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | vereeniging
# Processing Record 39 of Set 7 | skole
# Processing Record 40 of Set 7 | mar del plata
# Processing Record 41 of Set 7 | santander
# Processing Record 42 of Set 7 | kursk
# Processing Record 43 of Set 7 | bairiki
# Processing Record 44 of Set 7 | kaitangata
# Processing Record 45 of Set 7 | saint george
# Processing Record 46 of Set 7 | alenquer
# Processing Record 47 of Set 7 | iranshahr
# Processing Record 48 of Set 7 | havre-saint-pierre
# Processing Record 49 of Set 7 | jaque
# Processing Record 50 of Set 7 | airai
# Processing Record 1 of Set 8 | mount darwin
# Processing Record 2 of Set 8 | ihosy
# Processing Record 3 of Set 8 | prieska
# Processing Record 4 of Set 8 | mezen
# Processing Record 5 of Set 8 | general pico
# Processing Record 6 of Set 8 | mackenzie
# Processing Record 7 of Set 8 | popondetta
# Processing Record 8 of Set 8 | sheregesh
# Processing Record 9 of Set 8 | cap malheureux
# Processing Record 10 of Set 8 | mahebourg
# Processing Record 11 of Set 8 | crixas
# Processing Record 12 of Set 8 | megion
# Processing Record 13 of Set 8 | cape coast
# Processing Record 14 of Set 8 | vardo
# Processing Record 15 of Set 8 | kralendijk
# Processing Record 16 of Set 8 | greenville
# Processing Record 17 of Set 8 | green river
# Processing Record 18 of Set 8 | dingle
# Processing Record 19 of Set 8 | nueve de julio
# Processing Record 20 of Set 8 | kristiinankaupunki
# Processing Record 21 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 8 | den helder
# Processing Record 23 of Set 8 | provideniya
# Processing Record 24 of Set 8 | ye
# City not found. Skipping...
# Processing Record 25 of Set 8 | banda aceh
# Processing Record 26 of Set 8 | najran
# Processing Record 27 of Set 8 | umm lajj
# Processing Record 28 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 29 of Set 8 | atasu
# Processing Record 30 of Set 8 | hervey bay
# Processing Record 31 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 32 of Set 8 | ouesso
# Processing Record 33 of Set 8 | okrika
# Processing Record 34 of Set 8 | ancud
# Processing Record 35 of Set 8 | aneho
# Processing Record 36 of Set 8 | soe
# Processing Record 37 of Set 8 | lucea
# Processing Record 38 of Set 8 | quang ngai
# Processing Record 39 of Set 8 | wundanyi
# Processing Record 40 of Set 8 | saint-denis
# Processing Record 41 of Set 8 | kricim
# City not found. Skipping...
# Processing Record 42 of Set 8 | kaduqli
# Processing Record 43 of Set 8 | walvis bay
# Processing Record 44 of Set 8 | flinders
# Processing Record 45 of Set 8 | revda
# Processing Record 46 of Set 8 | otradnoye
# Processing Record 47 of Set 8 | bela vista
# Processing Record 48 of Set 8 | isla mujeres
# Processing Record 49 of Set 8 | campo de criptana
# Processing Record 50 of Set 8 | springbok
# Processing Record 1 of Set 9 | ban nahin
# Processing Record 2 of Set 9 | samarai
# Processing Record 3 of Set 9 | pleasanton
# Processing Record 4 of Set 9 | victoria
# Processing Record 5 of Set 9 | san rafael del sur
# Processing Record 6 of Set 9 | diffa
# Processing Record 7 of Set 9 | zabid
# Processing Record 8 of Set 9 | matara
# Processing Record 9 of Set 9 | kloulklubed
# Processing Record 10 of Set 9 | bilibino
# Processing Record 11 of Set 9 | riberalta
# Processing Record 12 of Set 9 | kabelvag
# Processing Record 13 of Set 9 | lafia
# Processing Record 14 of Set 9 | rehoboth
# Processing Record 15 of Set 9 | aleksandrovsk
# Processing Record 16 of Set 9 | peniche
# Processing Record 17 of Set 9 | broken hill
# Processing Record 18 of Set 9 | kawalu
# Processing Record 19 of Set 9 | garden city
# Processing Record 20 of Set 9 | rio gallegos
# Processing Record 21 of Set 9 | lichinga
# Processing Record 22 of Set 9 | boone
# Processing Record 23 of Set 9 | moron
# Processing Record 24 of Set 9 | umm kaddadah
# Processing Record 25 of Set 9 | mvuma
# Processing Record 26 of Set 9 | maarianhamina
# Processing Record 27 of Set 9 | trincomalee
# Processing Record 28 of Set 9 | soyo
# Processing Record 29 of Set 9 | perth
# Processing Record 30 of Set 9 | sao jose da coroa grande
# Processing Record 31 of Set 9 | faanui
# Processing Record 32 of Set 9 | lasa
# Processing Record 33 of Set 9 | vagay
# Processing Record 34 of Set 9 | hetauda
# Processing Record 35 of Set 9 | kaeo
# Processing Record 36 of Set 9 | lata
# Processing Record 37 of Set 9 | hokitika
# Processing Record 38 of Set 9 | mahendranagar
# Processing Record 39 of Set 9 | entebbe
# Processing Record 40 of Set 9 | gornozavodsk
# Processing Record 41 of Set 9 | albignasego
# Processing Record 42 of Set 9 | qibili
# City not found. Skipping...
# Processing Record 43 of Set 9 | rosario do sul
# Processing Record 44 of Set 9 | illela
# Processing Record 45 of Set 9 | kunda
# Processing Record 46 of Set 9 | puerto colombia
# Processing Record 47 of Set 9 | paita
# Processing Record 48 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 49 of Set 9 | padang
# Processing Record 50 of Set 9 | whitehorse
# Processing Record 1 of Set 10 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 10 | teya
# Processing Record 3 of Set 10 | puerto madryn
# Processing Record 4 of Set 10 | barry
# Processing Record 5 of Set 10 | phan thiet
# Processing Record 6 of Set 10 | marawi
# Processing Record 7 of Set 10 | darhan
# Processing Record 8 of Set 10 | mokhsogollokh
# Processing Record 9 of Set 10 | khandyga
# Processing Record 10 of Set 10 | unguia
# Processing Record 11 of Set 10 | guymon
# Processing Record 12 of Set 10 | lagoa
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | barcelona
# Processing Record 15 of Set 10 | soledad
# Processing Record 16 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 17 of Set 10 | butterworth
# Processing Record 18 of Set 10 | caravelas
# Processing Record 19 of Set 10 | mayumba
# Processing Record 20 of Set 10 | shingu
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | murovane
# Processing Record 23 of Set 10 | dubbo
# Processing Record 24 of Set 10 | mogzon
# Processing Record 25 of Set 10 | joensuu
# Processing Record 26 of Set 10 | maceio
# Processing Record 27 of Set 10 | asgabat
# Processing Record 28 of Set 10 | kumbo
# Processing Record 29 of Set 10 | labuhan
# Processing Record 30 of Set 10 | sucila
# Processing Record 31 of Set 10 | bronnoysund
# Processing Record 32 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 33 of Set 10 | vermilion
# Processing Record 34 of Set 10 | tynda
# Processing Record 35 of Set 10 | sargodha
# Processing Record 36 of Set 10 | cairns
# Processing Record 37 of Set 10 | santa helena de goias
# Processing Record 38 of Set 10 | coquimbo
# Processing Record 39 of Set 10 | salalah
# Processing Record 40 of Set 10 | portoferraio
# Processing Record 41 of Set 10 | cepu
# Processing Record 42 of Set 10 | teruel
# Processing Record 43 of Set 10 | lisakovsk
# Processing Record 44 of Set 10 | eresos
# Processing Record 45 of Set 10 | dunedin
# Processing Record 46 of Set 10 | bemidji
# Processing Record 47 of Set 10 | yamada
# Processing Record 48 of Set 10 | cidreira
# Processing Record 49 of Set 10 | kirakira
# Processing Record 50 of Set 10 | olinda
# Processing Record 1 of Set 11 | morondava
# Processing Record 2 of Set 11 | gweru
# Processing Record 3 of Set 11 | nemuro
# Processing Record 4 of Set 11 | lakatoro
# Processing Record 5 of Set 11 | shache
# Processing Record 6 of Set 11 | san felipe
# Processing Record 7 of Set 11 | boende
# Processing Record 8 of Set 11 | bhairab bazar
# Processing Record 9 of Set 11 | tazovskiy
# Processing Record 10 of Set 11 | jackson
# Processing Record 11 of Set 11 | chapais
# Processing Record 12 of Set 11 | rawson
# Processing Record 13 of Set 11 | zaporizhzhya
# Processing Record 14 of Set 11 | krasnovishersk
# Processing Record 15 of Set 11 | abay
# Processing Record 16 of Set 11 | novyy urgal
# Processing Record 17 of Set 11 | bonito
# Processing Record 18 of Set 11 | the pas
# Processing Record 19 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 20 of Set 11 | vestmanna
# Processing Record 21 of Set 11 | husavik
# Processing Record 22 of Set 11 | raudeberg
# Processing Record 23 of Set 11 | kieta
# Processing Record 24 of Set 11 | salinopolis
# Processing Record 25 of Set 11 | eureka
# Processing Record 26 of Set 11 | puerto madero
# Processing Record 27 of Set 11 | alice springs
# Processing Record 28 of Set 11 | gisborne
# Processing Record 29 of Set 11 | kropotkin
# Processing Record 30 of Set 11 | sijunjung
# Processing Record 31 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 32 of Set 11 | jidong
# Processing Record 33 of Set 11 | boa vista
# Processing Record 34 of Set 11 | staryy nadym
# Processing Record 35 of Set 11 | irinjalakuda
# Processing Record 36 of Set 11 | saint-medard-en-jalles
# Processing Record 37 of Set 11 | boralday
# Processing Record 38 of Set 11 | maridi
# Processing Record 39 of Set 11 | pemangkat
# Processing Record 40 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 11 | saint-pierre
# Processing Record 42 of Set 11 | moose factory
# Processing Record 43 of Set 11 | berlevag
# Processing Record 44 of Set 11 | asyut
# Processing Record 45 of Set 11 | lompoc
# Processing Record 46 of Set 11 | castle douglas
# Processing Record 47 of Set 11 | sault sainte marie
# Processing Record 48 of Set 11 | nizwa
# Processing Record 49 of Set 11 | kargasok
# Processing Record 50 of Set 11 | alofi
# Processing Record 1 of Set 12 | dehloran
# Processing Record 2 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 12 | kingston
# Processing Record 4 of Set 12 | gambela
# Processing Record 5 of Set 12 | saint-augustin
# Processing Record 6 of Set 12 | bundaberg
# Processing Record 7 of Set 12 | srandakan
# Processing Record 8 of Set 12 | kaffrine
# Processing Record 9 of Set 12 | jatai
# Processing Record 10 of Set 12 | ayagoz
# Processing Record 11 of Set 12 | marienburg
# Processing Record 12 of Set 12 | madimba
# Processing Record 13 of Set 12 | vila franca do campo
# Processing Record 14 of Set 12 | kaseda
# Processing Record 15 of Set 12 | seoul
# Processing Record 16 of Set 12 | quatre cocos
# Processing Record 17 of Set 12 | atyrau
# Processing Record 18 of Set 12 | shimoda
# Processing Record 19 of Set 12 | finnsnes
# Processing Record 20 of Set 12 | wilmington
# Processing Record 21 of Set 12 | nadym
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | hamilton
# Processing Record 24 of Set 12 | kearney
# Processing Record 25 of Set 12 | san ramon
# Processing Record 26 of Set 12 | potgietersrus
# City not found. Skipping...
# Processing Record 27 of Set 12 | yoichi
# Processing Record 28 of Set 12 | tabuk
# Processing Record 29 of Set 12 | keffi
# Processing Record 30 of Set 12 | zherdevka
# Processing Record 31 of Set 12 | miri
# Processing Record 32 of Set 12 | krasnokamensk
# Processing Record 33 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 12 | luanda
# Processing Record 35 of Set 12 | gigmoto
# Processing Record 36 of Set 12 | zyryanskoye
# Processing Record 37 of Set 12 | lana
# Processing Record 38 of Set 12 | sturgeon bay
# Processing Record 39 of Set 12 | ifanadiana
# Processing Record 40 of Set 12 | anuradhapura
# Processing Record 41 of Set 12 | abha
# Processing Record 42 of Set 12 | huarmey
# Processing Record 43 of Set 12 | vacaria
# Processing Record 44 of Set 12 | pandan
# Processing Record 45 of Set 12 | dinanagar
# Processing Record 46 of Set 12 | ballina
# Processing Record 47 of Set 12 | plastun
# Processing Record 48 of Set 12 | ostrovnoy
# Processing Record 49 of Set 12 | saldanha
# Processing Record 50 of Set 12 | zlatoustovsk
# City not found. Skipping...
# Processing Record 1 of Set 13 | cochrane
# Processing Record 2 of Set 13 | port-cartier
# Processing Record 3 of Set 13 | thinadhoo
# Processing Record 4 of Set 13 | yumen
# Processing Record 5 of Set 13 | aksarka
# Processing Record 6 of Set 13 | arica
# Processing Record 7 of Set 13 | neufchateau
# Processing Record 8 of Set 13 | ormara
# Processing Record 9 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 10 of Set 13 | svetlogorsk
# Processing Record 11 of Set 13 | belmonte
# Processing Record 12 of Set 13 | akot
# Processing Record 13 of Set 13 | woodstock
# Processing Record 14 of Set 13 | richards bay
# Processing Record 15 of Set 13 | port blair
# Processing Record 16 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 17 of Set 13 | mahina
# Processing Record 18 of Set 13 | winnemucca
# Processing Record 19 of Set 13 | mchinji
# Processing Record 20 of Set 13 | havant
# Processing Record 21 of Set 13 | dipkarpaz
# City not found. Skipping...
# Processing Record 22 of Set 13 | westport
# Processing Record 23 of Set 13 | itoman
# Processing Record 24 of Set 13 | port-gentil
# Processing Record 25 of Set 13 | valdivia
# Processing Record 26 of Set 13 | warwick
# Processing Record 27 of Set 13 | okhotsk
# Processing Record 28 of Set 13 | kruisfontein
# Processing Record 29 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 30 of Set 13 | kuryk
# Processing Record 31 of Set 13 | mabaruma
# Processing Record 32 of Set 13 | lodja
# Processing Record 33 of Set 13 | ranong
# Processing Record 34 of Set 13 | severo-kurilsk
# Processing Record 35 of Set 13 | markivka
# Processing Record 36 of Set 13 | yatou
# Processing Record 37 of Set 13 | visby
# Processing Record 38 of Set 13 | taksimo
# Processing Record 39 of Set 13 | levelland
# Processing Record 40 of Set 13 | port macquarie
# Processing Record 41 of Set 13 | the hammocks
# Processing Record 42 of Set 13 | sinyavino
# Processing Record 43 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 44 of Set 13 | waingapu
# Processing Record 45 of Set 13 | naroda
# Processing Record 46 of Set 13 | mecca
# Processing Record 47 of Set 13 | bolshaya atnya
# City not found. Skipping...
# Processing Record 48 of Set 13 | monticello
# Processing Record 49 of Set 13 | doka
# Processing Record 50 of Set 13 | nam tha
# City not found. Skipping...
# Processing Record 1 of Set 14 | aykhal
# Processing Record 2 of Set 14 | ati
# Processing Record 3 of Set 14 | hualmay
# Processing Record 4 of Set 14 | ust-ilimsk
# Processing Record 5 of Set 14 | sao felix do xingu
# Processing Record 6 of Set 14 | giovinazzo
# Processing Record 7 of Set 14 | lima
# Processing Record 8 of Set 14 | magistralnyy
# Processing Record 9 of Set 14 | anloga
# Processing Record 10 of Set 14 | hirara
# Processing Record 11 of Set 14 | katobu
# Processing Record 12 of Set 14 | manturovo
# Processing Record 13 of Set 14 | ha giang
# Processing Record 14 of Set 14 | garchitorena
# Processing Record 15 of Set 14 | mana
# Processing Record 16 of Set 14 | miranorte
# City not found. Skipping...
# Processing Record 17 of Set 14 | kismayo
# Processing Record 18 of Set 14 | srednekolymsk
# Processing Record 19 of Set 14 | shakhunya
# Processing Record 20 of Set 14 | charcas
# Processing Record 21 of Set 14 | radstadt
# Processing Record 22 of Set 14 | parelhas
# Processing Record 23 of Set 14 | yarada
# Processing Record 24 of Set 14 | litovko
# Processing Record 25 of Set 14 | sao miguel do iguacu
# Processing Record 26 of Set 14 | mogilno
# Processing Record 27 of Set 14 | amot
# Processing Record 28 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 29 of Set 14 | kholm-zhirkovskiy
# Processing Record 30 of Set 14 | lavrentiya
# Processing Record 31 of Set 14 | menongue
# Processing Record 32 of Set 14 | bathsheba
# Processing Record 33 of Set 14 | yabelo
# Processing Record 34 of Set 14 | grand gaube
# Processing Record 35 of Set 14 | ust-tsilma
# Processing Record 36 of Set 14 | elbistan
# Processing Record 37 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 14 | altay
# Processing Record 39 of Set 14 | sabang
# Processing Record 40 of Set 14 | urumqi
# Processing Record 41 of Set 14 | lexington
# Processing Record 42 of Set 14 | tessaoua
# Processing Record 43 of Set 14 | skibbereen
# Processing Record 44 of Set 14 | nyurba
# Processing Record 45 of Set 14 | ripoll
# Processing Record 46 of Set 14 | rocha
# Processing Record 47 of Set 14 | calbuco
# City not found. Skipping...
# Processing Record 48 of Set 14 | paramonga
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | kupino
# Processing Record 1 of Set 15 | yarim
# Processing Record 2 of Set 15 | bouna
# Processing Record 3 of Set 15 | shirgaon
# Processing Record 4 of Set 15 | sao lourenco do sul
# Processing Record 5 of Set 15 | harigue
# City not found. Skipping...
# Processing Record 6 of Set 15 | sorland
# Processing Record 7 of Set 15 | tiksi
# Processing Record 8 of Set 15 | camacha
# Processing Record 9 of Set 15 | hobyo
# Processing Record 10 of Set 15 | cap-aux-meules
# Processing Record 11 of Set 15 | vuktyl
# Processing Record 12 of Set 15 | mokokchung
# Processing Record 13 of Set 15 | bay roberts
# Processing Record 14 of Set 15 | istiaia
# Processing Record 15 of Set 15 | tezu
# Processing Record 16 of Set 15 | devils lake
# Processing Record 17 of Set 15 | karpathos
# Processing Record 18 of Set 15 | hovd
# Processing Record 19 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 15 | marsh harbour
# Processing Record 21 of Set 15 | lebedinyy
# Processing Record 22 of Set 15 | roald
# Processing Record 23 of Set 15 | ampanihy
# Processing Record 24 of Set 15 | kokoda
# Processing Record 25 of Set 15 | loiza
# Processing Record 26 of Set 15 | harper
# Processing Record 27 of Set 15 | newark
# Processing Record 28 of Set 15 | pangody
# Processing Record 29 of Set 15 | egvekinot
# Processing Record 30 of Set 15 | saint-joseph
# Processing Record 31 of Set 15 | suntar
# Processing Record 32 of Set 15 | honningsvag
# Processing Record 33 of Set 15 | potsdam
# Processing Record 34 of Set 15 | arvin
# Processing Record 35 of Set 15 | manaure
# Processing Record 36 of Set 15 | abnub
# Processing Record 37 of Set 15 | iguape
# Processing Record 38 of Set 15 | umea
# Processing Record 39 of Set 15 | verkhnevilyuysk
# Processing Record 40 of Set 15 | boyolangu
# Processing Record 41 of Set 15 | kayunga
# Processing Record 42 of Set 15 | vila velha
# Processing Record 43 of Set 15 | noyabrsk
# Processing Record 44 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 15 | zhigansk
# Processing Record 46 of Set 15 | darab
# Processing Record 47 of Set 15 | tecoanapa
# Processing Record 48 of Set 15 | isangel
# Processing Record 49 of Set 15 | bardiyah
# Processing Record 50 of Set 15 | shakiso
# Processing Record 1 of Set 16 | timmins
# Processing Record 2 of Set 16 | calvia
# Processing Record 3 of Set 16 | severnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Campbellsville  37.3434  -85.3419     54.68        69          61
# 1   Port Elizabeth -33.9180   25.5701     70.11        45           0
# 2           Mehamn  71.0357   27.8492     39.27        84         100
# 3        Busselton -33.6500  115.3333     61.09        74          94
# 4  Bambous Virieux -20.3428   57.7575     77.25        65          75
#
#    Wind Speed Country                 Date Current Description
# 0        3.00      US  2021-10-16 13:36:43       broken clouds
# 1       31.07      ZA  2021-10-16 13:33:49           clear sky
# 2       24.52      NO  2021-10-16 13:36:43          light rain
# 3       10.27      AU  2021-10-16 13:29:17     overcast clouds
# 4       16.11      MU  2021-10-16 13:36:44       broken clouds

# %%
# desired column orders
col_order=['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']

# %%
# reorder the dataframe cols
city_data_df=city_data_df[col_order]

# %%
city_data_df.head()
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0   Campbellsville      US  2021-10-16 13:36:43  37.3434  -85.3419     54.68
# 1   Port Elizabeth      ZA  2021-10-16 13:33:49 -33.9180   25.5701     70.11
# 2           Mehamn      NO  2021-10-16 13:36:43  71.0357   27.8492     39.27
# 3        Busselton      AU  2021-10-16 13:29:17 -33.6500  115.3333     61.09
# 4  Bambous Virieux      MU  2021-10-16 13:36:44 -20.3428   57.7575     77.25
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        69          61        3.00       broken clouds
# 1        45           0       31.07           clear sky
# 2        84         100       24.52          light rain
# 3        74          94       10.27     overcast clouds
# 4        65          75       16.11       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
